# %% [markdown]
# <a href="https://colab.research.google.com/github/eduardacdantas/biblioteca_numpy/blob/main/biblioteca_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dado = np.loadtxt('/content/apples_ts.csv', delimiter=',', usecols = np.arange(1,88,1))

# %%
dado
# Out:
# array([[  1.2013,   2.2013,   3.2013,   4.2013,   5.2013,   6.2013,
#           7.2013,   8.2013,   9.2013,  10.2013,  11.2013,  12.2013,
#           1.2014,   2.2014,   3.2014,   4.2014,   5.2014,   6.2014,
#           7.2014,   8.2014,   9.2014,  10.2014,  11.2014,  12.2014,
#           1.2015,   2.2015,   3.2015,   4.2015,   5.2015,   6.2015,
#           7.2015,   8.2015,   9.2015,  10.2015,  11.2015,  12.2015,
#           1.2016,   2.2016,   3.2016,   4.2016,   5.2016,   6.2016,
#           7.2016,   8.2016,   9.2016,  10.2016,  11.2016,  12.2016,
#           1.2017,   2.2017,   3.2017,   4.2017,   5.2017,   6.2017,
#           7.2017,   8.2017,   9.2017,  10.2017,  11.2017,  12.2017,
#           1.2018,   2.2018,   3.2018,   4.2018,   5.2018,   6.2018,
#           7.2018,   8.2018,   9.2018,  10.2018,  11.2018,  12.2018,
#           1.2019,   2.2019,   3.2019,   4.2019,   5.2019,   6.2019,
#           7.2019,   8.2019,   9.2019,  10.2019,  11.2019,  12.2019,
# ...

# %% [markdown]
# ndim - checa as dimensões do arquivo e o size - verifica a quantidade de dados estamos trabalhando

# %%
dado.ndim
# Out:
# 2

# %%
dado.size
# Out:
# 522

# %%
dado.shape
# Out:
# (6, 87)

# %% [markdown]
# .T - transposição - transoforma linhas em colunas

# %%
dado_transposto = dado.T

# %%
datas = dado_transposto[:,0]

# %%
precos = dado_transposto[:,1:6]

# %%
import matplotlib.pyplot as plt

# %%
datas = np.arange(1,88,1)

# %%
plt.plot(datas, precos[:,0])

# %%
Moscow = precos[:,0]
Kaliningrad = precos[:,1]
Petersburg = precos[:,2]
Kransodar = precos[:,3]
Ekaterinburg = precos[:,4]

# %%
Moscow.shape
# Out:
# (87,)

# %%
Moscow_ano1 = Moscow[0:12]
Moscow_ano2 = Moscow[12:24]
Moscow_ano3 = Moscow[24:36]
Moscow_ano4 = Moscow[36:48]

# %%
plt.plot(np.arange(1,13,1), Moscow_ano1)
plt.plot(np.arange(1,13,1), Moscow_ano2)
plt.plot(np.arange(1,13,1), Moscow_ano3)
plt.plot(np.arange(1,13,1), Moscow_ano4)
plt.legend(['ano1', 'ano2', 'ano3', 'ano4'])

# %%
plt.plot(datas,Kaliningrad)

# %%
sum(np.isnan(Kaliningrad))
# Out:
# 1

# %%
Kaliningrad[4] = np.mean([Kaliningrad[3], Kaliningrad[5]])

# %%
np.mean(Moscow)
# Out:
# 98.79781609195402

# %%
np.mean(Kaliningrad)
# Out:
# 74.5506896551724

# %% [markdown]
# y=ax+b - eq da reta

# %%
x = datas

# %%
y = 2*x+80

# %%
plt.plot(datas, Moscow)
plt.plot(x,y)

# %%
np.sum(np.power(Moscow - y,2))
# Out:
# 561349.9641

# %% [markdown]
# quanto menor o número, melhor a qualidade do ajuste

# %%
np.sqrt(np.sum(np.power(Moscow - y,2)))
# Out:
# 749.2329171225728

# %%
y = 0.52*x+80

# %%
plt.plot(datas, Moscow)
plt.plot(x,y)

# %%
np.sqrt(np.sum(np.power(Moscow - y,2)))
# Out:
# 110.48504740461489

# %% [markdown]
# valor muito menor para o ajuste da reta aos dados trabalhados, quanto menor melhor.

# %%
np.linalg.norm(Moscow-y)
# Out:
# 110.48504740461489

# %% [markdown]
# # **Regressão Linear:**
#
#
# 1.   Encontre o coeficiênte angular da reta.
# 2.   Encontre o coeficiente linear da reta.
# 3. Calcule qual a norm mais se ajusta ao modelo, ao resultados dos meus dados .
# 4. Plot os dados no gráfico juntos para ver com o valor que o cálculo encontrou.

# %% [markdown]
# Mas como eu calculo a e b da eq da reta de modo que não seja no chute? :

# %% [markdown]
# #Coeficiente angular
#
#
# a = coeficiente angular
# n = numero de elementos
# y = moscow
# x = datas
# O coeficiente angular pode ser obtido usando a equação:
#
# ![Capturar.PNG](data:image/png;base64,...)

# %%
Y = Moscow
X = datas
n = np.size(Moscow)

# %%
a = (n*np.sum(X*Y) - np.sum(X)*np.sum(Y))/(n*np.sum(X**2)-np.sum(X)**2)

# %%
a
# Out:
# 0.43520212145512926

# %% [markdown]
# #Coeficiente linear (b)
# b = media(Yi) - â * média (Xi)
#
# > Bloco com recuo

# %%
b = np.mean(Y) - a*np.mean(X)

# %%
y = a*X+b

# %%
np.linalg.norm(Moscow-y)
# Out:
# 101.7969539992751

# %%
plt.plot(datas, Moscow)
plt.plot(x,y)
plt.plot(41.5, 41.5*a+b, '*r')
plt.plot(100, 100*a+b, '*r')

# %% [markdown]
# Gerando números aleatórios com numpy

# %%
np.random.randint(low=40, high= 100, size=100)
# Out:
# array([97, 54, 76, 85, 76, 88, 69, 99, 85, 55, 42, 98, 47, 81, 55, 75, 46,
#        48, 54, 66, 91, 82, 95, 61, 45, 54, 98, 64, 74, 81, 94, 68, 96, 82,
#        66, 84, 86, 91, 88, 72, 58, 84, 51, 49, 45, 88, 89, 98, 66, 83, 41,
#        70, 97, 73, 62, 86, 72, 88, 86, 72, 97, 57, 75, 93, 63, 78, 73, 92,
#        99, 74, 49, 52, 95, 80, 69, 57, 57, 93, 40, 72, 54, 79, 50, 45, 78,
#        48, 70, 61, 69, 78, 66, 93, 79, 42, 57, 85, 76, 43, 98, 55])

# %%
coef_angulares = np.random.uniform(low=0.10, high= 0.90, size=100)

# %%
norma = np.array([])
for i in range(100):
  norma = np.append(norma, np.linalg.norm(Moscow-coef_angulares[i]*X+b))

# %%
norma
# Out:
# array([1590.86146224, 1618.52423422, 1573.17334236, 1556.4144692 ,
#        1569.33425875, 1539.12119305, 1503.75715471, 1402.87957516,
#        1577.62316202, 1588.312579  , 1607.09177694, 1582.29891074,
#        1573.01980969, 1411.49080798, 1318.5171466 , 1446.55989011,
#        1503.80501558, 1600.05365708, 1414.01788409, 1328.99142998,
#        1487.87999535, 1386.11181233, 1379.73740229, 1539.62471389,
#        1503.28537149, 1604.63259476, 1347.25095778, 1559.44477253,
#        1528.35099507, 1589.31145994, 1324.3842926 , 1552.1893839 ,
#        1543.22910756, 1477.02268739, 1540.62965658, 1573.36164526,
#        1597.07578359, 1306.99735779, 1332.11856614, 1322.21420531,
#        1475.04900295, 1308.00332584, 1543.16573981, 1625.58515317,
#        1306.57279785, 1468.57895198, 1604.03149684, 1620.4976956 ,
#        1412.62070446, 1435.99040893, 1414.53965796, 1569.90268546,
#        1383.41384142, 1368.68400108, 1533.08974104, 1444.52457815,
# ...

# %%
coef_angulares[1]
# Out:
# 0.5030624256795247

# %%
 np.random.uniform(low=0.10, high= 0.90, size=100)
# Out:
# array([0.62065622, 0.57363124, 0.64890158, 0.37594791, 0.60582026,
#        0.56161044, 0.57899381, 0.51719566, 0.66717987, 0.50378302,
#        0.10164081, 0.83966887, 0.3029458 , 0.56300177, 0.38876232,
#        0.42188294, 0.26965015, 0.52283481, 0.4410147 , 0.44220982,
#        0.72112348, 0.31336138, 0.13275344, 0.21613027, 0.71081477,
#        0.25524545, 0.58537036, 0.84317269, 0.52577069, 0.6813398 ,
#        0.52421623, 0.38338661, 0.2852592 , 0.69143023, 0.42782855,
#        0.5877328 , 0.68268727, 0.63940947, 0.8475788 , 0.53450848,
#        0.8510021 , 0.43600477, 0.35866997, 0.79059675, 0.31983249,
#        0.7379754 , 0.29571048, 0.18114555, 0.36820147, 0.42798946,
#        0.54624347, 0.60306338, 0.59341895, 0.50607353, 0.11543714,
#        0.3677243 , 0.47567213, 0.10977265, 0.11758328, 0.62302372,
#        0.70389897, 0.55761101, 0.26154627, 0.3033385 , 0.4043515 ,
#        0.54459982, 0.39032542, 0.78043561, 0.35534178, 0.45211719,
# ...

# %%
np.random.seed(84)   #gera a mesma sequência de números aleatórios mesmo que você e a outra pessoa esteja em máquinas diferentes
np.random.uniform(low=0.10, high= 0.90, size=100)
# Out:
# array([0.13683279, 0.39619385, 0.29385461, 0.602784  , 0.89208805,
#        0.20447044, 0.23887133, 0.30665125, 0.43471917, 0.20481511,
#        0.3323601 , 0.49624488, 0.87360345, 0.33791189, 0.62144155,
#        0.52849032, 0.8096211 , 0.7916786 , 0.85242626, 0.18466651,
#        0.59057786, 0.24287265, 0.15934165, 0.89674619, 0.38501918,
#        0.77157959, 0.61045713, 0.2676991 , 0.88274155, 0.21072909,
#        0.54257849, 0.3133875 , 0.34935345, 0.36479868, 0.21666475,
#        0.75660734, 0.22889395, 0.4986747 , 0.36482516, 0.25587381,
#        0.21706205, 0.64938079, 0.89569528, 0.32780566, 0.55295355,
#        0.19624604, 0.13469036, 0.22628157, 0.44641143, 0.40177235,
#        0.1481411 , 0.59986997, 0.49023732, 0.4293729 , 0.46122788,
#        0.54208756, 0.84785549, 0.31153122, 0.11414346, 0.65873013,
#        0.74587422, 0.61387426, 0.52200325, 0.76589084, 0.38088747,
#        0.25165091, 0.11382762, 0.88457997, 0.74881915, 0.86863621,
# ...

# %%
np.random.seed(84)
coef_angulares = np.random.uniform(low=0.10, high= 0.90, size=100)
norma = np.array([])
for i in range(100):
  norma = np.append(norma, np.linalg.norm(Moscow-(coef_angulares[i]*X+b)))

# %%
norma
# Out:
# array([173.90151233, 103.45241986, 121.75367289, 128.97173036,
#        238.69504078, 149.16590195, 137.73123242, 118.54419212,
#        101.79720981, 149.04689147, 112.80225228, 105.8049351 ,
#        230.82444742, 111.69709582, 134.56525603, 110.93209631,
#        204.12484401, 196.82117307, 221.88687726, 156.13691054,
#        125.51272174, 136.46474504, 165.39506278, 240.68784732,
#        104.52254473, 188.75637903, 131.2292927 , 128.94885341,
#        234.70773582, 147.01799832, 113.7418054 , 116.94496221,
#        109.58257043, 107.09546548, 145.00728041, 182.83818792,
#        140.95017242, 106.12371866, 107.0915778 , 132.45242448,
#        144.8736358 , 143.54772697, 240.23793834, 113.74604121,
#        116.01191029, 152.02977343, 174.72333708, 141.8068161 ,
#        101.93467119, 103.01538109, 169.59787792, 128.13083711,
#        105.06648948, 101.83421597, 102.53716362, 113.63850533,
#        219.96993004, 117.37921502, 182.70217805, 146.69612581,
# ...

# %%
coef_angulares
# Out:
# array([0.13683279, 0.39619385, 0.29385461, 0.602784  , 0.89208805,
#        0.20447044, 0.23887133, 0.30665125, 0.43471917, 0.20481511,
#        0.3323601 , 0.49624488, 0.87360345, 0.33791189, 0.62144155,
#        0.52849032, 0.8096211 , 0.7916786 , 0.85242626, 0.18466651,
#        0.59057786, 0.24287265, 0.15934165, 0.89674619, 0.38501918,
#        0.77157959, 0.61045713, 0.2676991 , 0.88274155, 0.21072909,
#        0.54257849, 0.3133875 , 0.34935345, 0.36479868, 0.21666475,
#        0.75660734, 0.22889395, 0.4986747 , 0.36482516, 0.25587381,
#        0.21706205, 0.64938079, 0.89569528, 0.32780566, 0.55295355,
#        0.19624604, 0.13469036, 0.22628157, 0.44641143, 0.40177235,
#        0.1481411 , 0.59986997, 0.49023732, 0.4293729 , 0.46122788,
#        0.54208756, 0.84785549, 0.31153122, 0.11414346, 0.65873013,
#        0.74587422, 0.61387426, 0.52200325, 0.76589084, 0.38088747,
#        0.25165091, 0.11382762, 0.88457997, 0.74881915, 0.86863621,
# ...

# %%
dados = np.column_stack([norma, coef_angulares])

# %%
dados.shape
# Out:
# (100, 2)

# %%
np.savetxt('dados.csv', dados, delimiter=',')

# %% [markdown]
# #Fim do módulo de numpy!!
